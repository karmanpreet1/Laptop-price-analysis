# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import os

# %%
df = pd.read_csv('/content/amazon_laptop_prices_v01 (1).csv')

# %%
df
# Out:
#       brand                   model   screen_size       color harddisk  \
# 0      ROKC                     NaN     14 Inches        Blue  1000 GB
# 1        HP                     NaN   15.6 Inches      Silver  1000 GB
# 2       MSI   Vector GP66 12UGS-267  15.66 Inches  Core Black      NaN
# 3     Apple             MacBook Air   13.3 Inches      Silver   256 GB
# 4     Apple             MacBook Air   15.3 Inches    Midnight   256 GB
# ...     ...                     ...           ...         ...      ...
# 4441    MSI  Stealth GS66 12UGS-025   15.6 Inches  Core Black      NaN
# 4442   ROKC                     NaN     14 Inches        Blue  1000 GB
# 4443   Dell    Inspiron 3511 Laptop   15.6 Inches       Black   512 GB
# 4444   Dell    Latitude 3420 Laptop     14 Inches         NaN   512 GB
# 4445   Dell    Latitude 5430 Laptop     14 Inches       Black   256 GB
#
#                 cpu    ram               OS  special_features    graphics  \
# ...

# %%
df.head()
# Out:
#    brand                  model   screen_size       color harddisk  \
# 0   ROKC                    NaN     14 Inches        Blue  1000 GB
# 1     HP                    NaN   15.6 Inches      Silver  1000 GB
# 2    MSI  Vector GP66 12UGS-267  15.66 Inches  Core Black      NaN
# 3  Apple            MacBook Air   13.3 Inches      Silver   256 GB
# 4  Apple            MacBook Air   15.3 Inches    Midnight   256 GB
#
#              cpu    ram               OS  special_features    graphics  \
# 0  Intel Core i7   8 GB       Windows 11               NaN  Integrated
# 1  Intel Core i5  64 GB   Windows 11 Pro  Backlit Keyboard  Integrated
# 2  Intel Core i9  32 GB  Windows 11 Home               NaN   Dedicated
# 3        Unknown   8 GB           Mac OS  Backlit Keyboard  Integrated
# 4        Unknown   8 GB           Mac OS               NaN  Integrated
#
#   graphics_coprocessor cpu_speed  rating        Price  Sale Product Count  \
# ...

# %%
df.shape
# Out:
# (4446, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4446 entries, 0 to 4445
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   brand                 4446 non-null   object
#  1   model                 3282 non-null   object
#  2   screen_size           4417 non-null   object
#  3   color                 3867 non-null   object
#  4   harddisk              3870 non-null   object
#  5   cpu                   4346 non-null   object
#  6   ram                   4385 non-null   object
#  7   OS                    4420 non-null   object
#  8   special_features      2054 non-null   object
#  9   graphics              4381 non-null   object
#  10  graphics_coprocessor  2574 non-null   object
#  11  cpu_speed             1520 non-null   object
#  12  rating                2174 non-null   float64
#  13  Price                 4446 non-null   object
#  14  Sale Product Count    4446 non-null   int64
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#             rating  Sale Product Count  Available Stock
# count  2174.000000         4446.000000      3904.000000
# mean      4.086891           38.614035       291.502305
# std       1.165337           15.799487       120.966996
# min       1.000000           12.000000        80.000000
# 25%       4.000000           25.000000       187.000000
# 50%       4.500000           38.000000       292.000000
# 75%       5.000000           53.000000       395.000000
# max       5.000000           65.000000       500.000000

# %%
df.dtypes
# Out:
# brand                    object
# model                    object
# screen_size              object
# color                    object
# harddisk                 object
# cpu                      object
# ram                      object
# OS                       object
# special_features         object
# graphics                 object
# graphics_coprocessor     object
# cpu_speed                object
# rating                  float64
# Price                    object
# Sale Product Count        int64
# Total Sales              object
# Available Stock         float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4446 entries, 0 to 4445
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   brand                 4446 non-null   object
#  1   model                 3282 non-null   object
#  2   screen_size           4417 non-null   object
#  3   color                 3867 non-null   object
#  4   harddisk              3870 non-null   object
#  5   cpu                   4346 non-null   object
#  6   ram                   4385 non-null   object
#  7   OS                    4420 non-null   object
#  8   special_features      2054 non-null   object
#  9   graphics              4381 non-null   object
#  10  graphics_coprocessor  2574 non-null   object
#  11  cpu_speed             1520 non-null   object
#  12  rating                2174 non-null   float64
#  13  Price                 4446 non-null   object
#  14  Sale Product Count    4446 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# brand                      0
# model                   1164
# screen_size               29
# color                    579
# harddisk                 576
# cpu                      100
# ram                       61
# OS                        26
# special_features        2392
# graphics                  65
# graphics_coprocessor    1872
# cpu_speed               2926
# rating                  2272
# Price                      0
# Sale Product Count         0
# Total Sales                0
# Available Stock          542
# dtype: int64

# %%
df.dropna(subset=['model', 'cpu_speed', 'ram'], inplace=True)

# %%
df
# Out:
#        brand                   model   screen_size         color harddisk  \
# 2        MSI   Vector GP66 12UGS-267  15.66 Inches    Core Black      NaN
# 26      ASUS           ROG Strix G16     16 Inches  Eclipse Gray      NaN
# 27       MSI  Stealth GS66 12UGS-025   15.6 Inches    Core Black      NaN
# 31       MSI   Vector GP66 12UGS-267  15.66 Inches    Core Black      NaN
# 49    Lenovo                  Flex 5     14 Inches           NaN   256 GB
# ...      ...                     ...           ...           ...      ...
# 4438     MSI   Vector GP66 12UGS-267  15.66 Inches    Core Black      NaN
# 4439     MSI  Stealth GS66 12UGS-025   15.6 Inches    Core Black      NaN
# 4440     MSI   Vector GP66 12UGS-267  15.66 Inches    Core Black      NaN
# 4441     MSI  Stealth GS66 12UGS-025   15.6 Inches    Core Black      NaN
# 4444    Dell    Latitude 3420 Laptop     14 Inches           NaN   512 GB
#
#                     cpu    ram               OS special_features    graphics  \
# ...

# %%
df.isnull().sum()
# Out:
# brand                     0
# model                     0
# screen_size               1
# color                   187
# harddisk                452
# cpu                      21
# ram                       0
# OS                        3
# special_features        603
# graphics                  4
# graphics_coprocessor    285
# cpu_speed                 0
# rating                   96
# Price                     0
# Sale Product Count        0
# Total Sales               0
# Available Stock          56
# dtype: int64

# %%
for i in df.columns:
  print(i,":",df[i].unique())
# Out:
# brand : ['MSI' 'ASUS' 'Lenovo' 'HP' 'Apple' 'SAMSUNG' 'LG' 'Dell'
#  'Quality Refurbished Computers' 'acer' 'Microsoft' 'Razer' 'Alienware'
#  'hp' 'Latitude' 'Toughbook' 'lenovo' 'Mytrix']
# model : ['Vector GP66 12UGS-267' 'ROG Strix G16' 'Stealth GS66 12UGS-025' 'Flex 5'
#  'Chromebook 11 G9 EE' 'MacBook Pro'
#  '2022 Apple MacBook Air M2, 16GB RAM, 256GB Storage - Space Gray (Z15S000CT)'
#  'ProArt StudioBook 16' 'Chromebook 4+' 'FX707ZC-ES53' 'NP964XFG-KC1US'
#  'ASUS Chromebook CX1' '16Z90RS-K.ADW8U1' 'Katana 17 B13VFK-835US'
#  '82XQ001GUS' 'ASUS ZenBook Pro Duo 15' 'ASUS Laptop L210' '6M0Z7UA#ABA'
#  'TUF Gaming F15' '16Z90RS-K.AAW7U1' '14Z90RS-K.ADW9U1' 'XE530QDA-KB1US'
#  'LG Gram' 'Inspiron' 'S5402ZA-IS74' 'ExpertBook B9'
#  'Latitude 5340 Multi-Touch 2-in-1' 'Lenovo Thinkpad' 'Vivobook Pro 16X'
#  'PMTF1' 'Vivobook 15X' 'Latitude' 'Vivobook 15'
#  'Prestige 13Evo A13M-050US' 'ASUS Chromebook'
#  'Prestige 16Studio A13VF-039US' 'Dell Latitude' '15-eh2085cl' 'Vulcan 17'
# ...

# %%
plt.figure(figsize=(10, 8))
plt.subplot(4, 2, 1)
top_brands = df['brand'].value_counts().nlargest(10)
sns.barplot(x=top_brands.values, y=top_brands.index, palette="viridis")
plt.title('Top 10 Brands')
# Out:
# Text(0.5, 1.0, 'Top 10 Brands')

# %%
plt.figure(figsize=(10, 8))
plt.subplot(4, 2, 2)
top_models = df['model'].value_counts().nlargest(10)
sns.barplot(x=top_models.values, y=top_models.index, palette="magma")
plt.title('Top 10 Models')
# Out:
# Text(0.5, 1.0, 'Top 10 Models')

# %%
plt.subplot(4, 2, 7)
plt.figure(figsize=(10, 8))
sns.boxplot(x=df['ram'], color='lightgreen')
plt.title('RAM Distribution')
# Out:
# Text(0.5, 1.0, 'RAM Distribution')

# %%
plt.figure(figsize=(10, 8))
plt.subplot(4, 2, 1)
top_brands = df['brand'].value_counts().nlargest(10)
sns.barplot(x=top_brands.values, y=top_brands.index, palette="viridis")
plt.title('Top 10 Brands')
# Out:
# Text(0.5, 1.0, 'Top 10 Brands')

# %%
plt.figure(figsize=(25, 25))
plt.subplot(4, 2, 8)
os_counts = df['OS'].value_counts()
plt.pie(os_counts.values, labels=os_counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette("tab20c"))
plt.title('OS Distribution')
# Out:
# Text(0.5, 1.0, 'OS Distribution')

# %%
plt.figure(figsize=(10, 8))
sns.histplot(df['Price'], kde=True)
plt.title("Price Distribution")
plt.show()

# %%
plt.figure(figsize=(10, 8))
top_brands = df['brand'].value_counts().index[:5]
plt.figure()
sns.boxplot(data=df[df['brand'].isin(top_brands)], x='brand', y='Price')
plt.title("Price Distribution by Top Brands")
plt.xticks(rotation=45)
plt.show()

# %%
sns.scatterplot(x='ram', y='Price', data=df)
# Out:
# <Axes: xlabel='ram', ylabel='Price'>

# %%
plt.figure(figsize=(10,6))

corr = df[['Price','rating','ram','cpu_speed','Available Stock']].corr()

sns.heatmap(corr, annot=True, cmap='Purples')

plt.title('Correlation Heatmap (Purple)')
plt.show()

# %%
from sklearn.cluster import KMeans

# Select features
X = df[['Price','ram','rating']].dropna()

wcss = []

for i in range(1,11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(8,5))
plt.plot(range(1,11), wcss, marker='o')

plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()
